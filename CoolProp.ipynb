# %% [markdown]
# <a href="https://colab.research.google.com/github/ilyas29akhmetov/lab/blob/main/CoolProp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Система уравнений

# %%
import numpy as np
from scipy.optimize import fsolve
def f(p):
  x,y=p
  return(x**2+y*x-10,x*y+y**2+np.sin(x)+7)
x,y= fsolve(f,(1,3))
print(x,y)
# Out:
# 5.031943969582944 -3.04464044227471

# %% [markdown]
# Функция coolprop

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting CoolProp
#   Downloading CoolProp-6.4.3.post1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 35.0 MB/s eta 0:00:00
# Installing collected packages: CoolProp
# Successfully installed CoolProp-6.4.3.post1

# %%
import CoolProp.CoolProp as ct 
import matplotlib.pyplot as plt
t=np.linspace(283.15,400.15,500)
p=101325
d=ct.PropsSI("D","T",t,"P",p,"water")

plt.plot(t,d)
plt.title("Самый лучший график в мире")
plt.xlabel("ось температуры в Кельвинах")
plt.ylabel("ось плотности")
plt.scatter(373.15,957,color="black")
plt.grid()
plt.show()
